# %% [markdown]
# # Etapa 1 - Análise Exploratória de Dados (EDA)
#
# Dataset: CDC Diabetes Health Indicators (BRFSS 2015).
#
# Este notebook apenas orquestra e renderiza a lógica implementada em `src/eda.py`.
# Toda figura/tabela também é salva em `outputs/figures/` e `outputs/metrics/` ao rodar
# `python -m src.eda`.

# %%
import sys
from pathlib import Path

# Permite importar `config` e o pacote `src` a partir da raiz do projeto.
ROOT = Path.cwd().parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import config
from src import data_loading, eda, plotting

config.set_seeds()
plotting.set_style()

# %% [markdown]
# ## 1. Visão geral do dataset e tipos de atributos

# %%
eda.dataset_overview()
# Out:
#        tarefa                                          arquivo  n_amostras  \
# 0      binary  diabetes_binary_health_indicators_BRFSS2015.csv      253680
# 1  multiclass     diabetes_012_health_indicators_BRFSS2015.csv      253680
# 2  regression  diabetes_binary_health_indicators_BRFSS2015.csv      253680
#
#    n_atributos             alvo              tipo_problema
# 0           21  Diabetes_binary      classificação binária
# 1           21     Diabetes_012  classificação multiclasse
# 2           21              BMI                  regressão

# %%
eda.feature_types_table()
# Out:
#                  feature                         tipo
# 0                 HighBP                binária (0/1)
# 1               HighChol                binária (0/1)
# 2              CholCheck                binária (0/1)
# 3                    BMI          contínua / contagem
# 4                 Smoker                binária (0/1)
# 5                 Stroke                binária (0/1)
# 6   HeartDiseaseorAttack                binária (0/1)
# 7           PhysActivity                binária (0/1)
# 8                 Fruits                binária (0/1)
# 9                Veggies                binária (0/1)
# 10     HvyAlcoholConsump                binária (0/1)
# 11         AnyHealthcare                binária (0/1)
# 12           NoDocbcCost                binária (0/1)
# 13               GenHlth  ordinal (inteiro com ordem)
# 14              MentHlth          contínua / contagem
# 15              PhysHlth          contínua / contagem
# ...

# %%
df_bin = data_loading.load_dataset("binary")
df_multi = data_loading.load_dataset("multiclass")
print("binário:", df_bin.shape, "| multiclasse:", df_multi.shape)
# Out:
# binário: (253680, 22) | multiclasse: (253680, 22)

# %% [markdown]
# ## 2. Estatísticas descritivas e valores ausentes

# %%
eda.summary_statistics(df_bin)
# Out:
#                          count       mean       std   min   25%   50%   75%  \
# Diabetes_binary       253680.0   0.139333  0.346294   0.0   0.0   0.0   0.0
# HighBP                253680.0   0.429001  0.494934   0.0   0.0   0.0   1.0
# HighChol              253680.0   0.424121  0.494210   0.0   0.0   0.0   1.0
# CholCheck             253680.0   0.962670  0.189571   0.0   1.0   1.0   1.0
# BMI                   253680.0  28.382364  6.608694  12.0  24.0  27.0  31.0
# Smoker                253680.0   0.443169  0.496761   0.0   0.0   0.0   1.0
# Stroke                253680.0   0.040571  0.197294   0.0   0.0   0.0   0.0
# HeartDiseaseorAttack  253680.0   0.094186  0.292087   0.0   0.0   0.0   0.0
# PhysActivity          253680.0   0.756544  0.429169   0.0   1.0   1.0   1.0
# Fruits                253680.0   0.634256  0.481639   0.0   0.0   1.0   1.0
# Veggies               253680.0   0.811420  0.391175   0.0   1.0   1.0   1.0
# ...

# %%
print("Total de valores ausentes (dataset binário):", int(df_bin.isna().sum().sum()))
# Out:
# Total de valores ausentes (dataset binário): 0

# %% [markdown]
# ## 3. Distribuição das classes (desbalanceamento)

# %%
display(eda.class_distribution(df_bin, config.TARGET_BINARY))
display(eda.class_distribution(df_multi, config.TARGET_MULTICLASS))
# Out:
#    classe  contagem  percentual
# 0     0.0    218334       86.07
# 1     1.0     35346       13.93
#    classe  contagem  percentual
# 0     0.0    213703       84.24
# 1     1.0      4631        1.83
# 2     2.0     35346       13.93

# %%
eda.plot_class_distribution(
    df_bin, config.TARGET_BINARY, config.CLASS_LABELS_BINARY,
    "etapa1_dist_classes_binaria.png", "Distribuição das classes — binária")
eda.plot_class_distribution(
    df_multi, config.TARGET_MULTICLASS, config.CLASS_LABELS_MULTICLASS,
    "etapa1_dist_classes_multiclasse.png", "Distribuição das classes — multiclasse")
# Out:
# WindowsPath('C:/Users/Tobias Viero/Desktop/Trabalho 5/outputs/figures/etapa1_dist_classes_multiclasse.png')

# %% [markdown]
# ## 4. BMI - distribuição e outliers

# %%
eda.plot_bmi_distribution(df_bin)
# Out:
# WindowsPath('C:/Users/Tobias Viero/Desktop/Trabalho 5/outputs/figures/etapa1_bmi_dist.png')

# %% [markdown]
# ## 5. Correlação entre atributos

# %%
eda.plot_correlation_heatmap(df_bin)
# Out:
# WindowsPath('C:/Users/Tobias Viero/Desktop/Trabalho 5/outputs/figures/etapa1_correlacao.png')

# %%
# Pares com |correlação| >= 0.5
eda.high_correlations(df_bin)
# Out:
#   feature_a feature_b  correlacao
# 0   GenHlth  PhysHlth       0.524

# %% [markdown]
# ## 6. Features vs. alvo

# %%
eda.plot_features_vs_target(df_bin, config.TARGET_BINARY, config.CLASS_LABELS_BINARY)
# Out:
# WindowsPath('C:/Users/Tobias Viero/Desktop/Trabalho 5/outputs/figures/etapa1_features_vs_target.png')

# %% [markdown]
# ## 7. Gerar todos os artefatos de uma vez
#
# Equivalente a rodar `python -m src.eda` no terminal.

# %%
eda.run()
# Out:
# Carregando datasets...
# Gerando tabelas-resumo...
# Gerando figuras...
# Gerando discussão (markdown)...
#
# EDA concluída.
#   Figuras salvas em: C:\Users\Tobias Viero\Desktop\Trabalho 5\outputs\figures
#   Métricas salvas em: C:\Users\Tobias Viero\Desktop\Trabalho 5\outputs\metrics
